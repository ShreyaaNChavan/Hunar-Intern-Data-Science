# %% [markdown]
# ## Data Description

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(
    r"C:\Users\admin\Desktop\Hunar-Intern-Data-Sci\dataset\breast cancer.csv",
    index_col=0
)
df
# Out:
#          diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# id
# 842302           M        17.99         10.38          122.80     1001.0
# 842517           M        20.57         17.77          132.90     1326.0
# 84300903         M        19.69         21.25          130.00     1203.0
# 84348301         M        11.42         20.38           77.58      386.1
# 84358402         M        20.29         14.34          135.10     1297.0
# ...            ...          ...           ...             ...        ...
# 926424           M        21.56         22.39          142.00     1479.0
# 926682           M        20.13         28.25          131.20     1261.0
# 926954           M        16.60         28.08          108.30      858.1
# 927241           M        20.60         29.33          140.10     1265.0
# 92751            B         7.76         24.54           47.92      181.0
#
#           smoothness_mean  compactness_mean  concavity_mean  \
# id
# ...

# %%
df.shape
# Out:
# (569, 31)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 569 entries, 842302 to 92751
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   diagnosis                569 non-null    object
#  1   radius_mean              569 non-null    float64
#  2   texture_mean             569 non-null    float64
#  3   perimeter_mean           569 non-null    float64
#  4   area_mean                569 non-null    float64
#  5   smoothness_mean          569 non-null    float64
#  6   compactness_mean         569 non-null    float64
#  7   concavity_mean           569 non-null    float64
#  8   concave_points_mean      569 non-null    float64
#  9   symmetry_mean            569 non-null    float64
#  10  fractal_dimension_mean   569 non-null    float64
#  11  radius_se                569 non-null    float64
#  12  texture_se               569 non-null    float64
# ...

# %%
df.describe()
# Out:
#        radius_mean  texture_mean  perimeter_mean    area_mean  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave_points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# ...

# %%
df.isnull().sum()
# Out:
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave_points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave_points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave_points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# dtype: int64

# %%
df['diagnosis'].value_counts()
# Out:
# diagnosis
# B    357
# M    212
# Name: count, dtype: int64

# %%
df['diagnosis'].unique()
# Out:
# array(['M', 'B'], dtype=object)

# %%
sns.countplot(x= "diagnosis",data= df)
# Out:
# <Axes: xlabel='diagnosis', ylabel='count'>

# %%
df['diagnosis'] = df['diagnosis'].map({'M': 1, 'B': 0})

plt.figure(figsize=(30,30))
sns.heatmap(df.corr(),annot= True)
# Out:
# <Axes: >

# %%
features = [
    'radius_mean',
    'texture_mean',
    'perimeter_mean',
    'area_mean',
    'smoothness_mean',
    'diagnosis'
]

sns.pairplot(df[features], hue='diagnosis')

# %% [markdown]
# ## Data  Preparation

# %%
from sklearn.preprocessing import LabelEncoder
Label_Encoder= LabelEncoder()
df['diagnosis'] = Label_Encoder.fit_transform(df['diagnosis'])

# %%
df['diagnosis'].value_counts()
# Out:
# diagnosis
# 0    357
# 1    212
# Name: count, dtype: int64

# %%
df['diagnosis'] = df['diagnosis'].astype(int)
X = df.drop('diagnosis', axis=1)
y = df['diagnosis']


print(y.isna().sum())        # must be 0
print(y.value_counts())
# Out:
# 0
# diagnosis
# 0    357
# 1    212
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.25,
    random_state=42,
    stratify=y
)

# %%
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(X_train)
x_test = sc.transform(X_test)

# %% [markdown]
# ## Model Selection

# %%
#Using KNeighborsClassifier Method of neighbors class to use Nearest Neighbor algorithm
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors = 5, metric = 'manhattan', p = 2)
classifier.fit(x_train, y_train)
Y2_pred = classifier.predict(x_test)
accuracy_score(y_test,Y2_pred)
# Out:
# 0.972027972027972

# %%
from sklearn.model_selection import cross_val_score

accuracy_rate=[]

for i in range(1,40):
    classifier= KNeighborsClassifier(n_neighbors =i)
    score = cross_val_score(classifier,X,Y,cv=10)
    accuracy_rate.append(score.mean())

# %%
accuracy_rate
# Out:
# [np.float64(0.9156954887218045),
#  np.float64(0.9121240601503761),
#  np.float64(0.9261904761904761),
#  np.float64(0.9227130325814535),
#  np.float64(0.9297619047619046),
#  np.float64(0.9297619047619048),
#  np.float64(0.9279761904761905),
#  np.float64(0.924436090225564),
#  np.float64(0.9262531328320801),
#  np.float64(0.9227130325814535),
#  np.float64(0.9297619047619046),
#  np.float64(0.9279761904761903),
#  np.float64(0.9315162907268169),
#  np.float64(0.9332706766917293),
#  np.float64(0.9297619047619046),
#  np.float64(0.9297305764411027),
#  np.float64(0.9297619047619048),
#  np.float64(0.9279761904761905),
#  np.float64(0.9315162907268169),
#  np.float64(0.9297619047619048),
#  np.float64(0.9297619047619048),
#  np.float64(0.9280075187969924),
#  np.float64(0.9280075187969924),
#  np.float64(0.9280075187969924),
#  np.float64(0.9280075187969924),
#  np.float64(0.9244987468671679),
#  np.float64(0.9244987468671679),
#  np.float64(0.9227130325814537),
# ...

# %%
plt.plot(range(1,40),accuracy_rate, color= 'green',linestyle = 'dashed',marker='*', markersize=10)
plt.title('Accuracy Rate vs K-Value')
plt.xlabel('K-Value')
plt.ylabel('Accuracy_Rate')
# Out:
# Text(0, 0.5, 'Accuracy_Rate')

# %%
from sklearn import metrics
fpr,tpr,thresholds = metrics.roc_curve(y_test,Y2_pred)
metrics.auc(fpr, tpr)
# Out:
# np.float64(0.9622641509433962)

# %%
plt.plot(fpr,tpr, linestyle = 'dashed', marker='*')

# %%
#for K Value=17
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors = 17, metric = 'manhattan', p = 2)
classifier.fit(x_train, y_train)
Y2_pred = classifier.predict(x_test)
accuracy_score(y_test,Y2_pred)
# Out:
# 0.958041958041958

# %%
#for K Value=18
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors = 18, metric = 'manhattan', p = 2)
classifier.fit(x_train, y_train)
Y2_pred = classifier.predict(x_test)
accuracy_score(y_test,Y2_pred)
# Out:
# 0.958041958041958

# %%
#for K Value=19
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors = 19, metric = 'manhattan', p = 2)
classifier.fit(x_train, y_train)
Y2_pred = classifier.predict(x_test)
accuracy_score(y_test,Y2_pred)
# Out:
# 0.958041958041958

# %%
#for K Value=20
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors = 20, metric = 'manhattan', p = 2)
classifier.fit(x_train, y_train)
Y2_pred = classifier.predict(x_test)
accuracy_score(y_test,Y2_pred)
# Out:
# 0.951048951048951

# %%
#for K Value=23
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors = 23, metric = 'manhattan', p = 2)
classifier.fit(x_train, y_train)
Y2_pred = classifier.predict(x_test)
accuracy_score(y_test,Y2_pred)
# Out:
# 0.958041958041958

# %%
#for K Value=24
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors = 24, metric = 'manhattan', p = 2)
classifier.fit(x_train, y_train)
Y2_pred = classifier.predict(x_test)
accuracy_score(y_test,Y2_pred)
# Out:
# 0.958041958041958

# %% [markdown]
# ## Train the **final KNN model**

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

final_model = KNeighborsClassifier(
    n_neighbors=17,
    metric='manhattan'
)

final_model.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(metric='manhattan', n_neighbors=17)

# %%
y_pred = final_model.predict(x_test)

accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.958041958041958

# %%
#Confusion Matrix

print(confusion_matrix(y_test, y_pred))
# Out:
# [[66 24]
#  [28 25]]

# %%
#Classification Report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.70      0.73      0.72        90
#            1       0.51      0.47      0.49        53
#
#     accuracy                           0.64       143
#    macro avg       0.61      0.60      0.60       143
# weighted avg       0.63      0.64      0.63       143

# %% [markdown]
# ## Save the model (Reuse without retraining)

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
import joblib

pipeline = Pipeline([
    ('scaler', StandardScaler()),
    ('knn', KNeighborsClassifier(n_neighbors=17, metric='manhattan'))
])

pipeline.fit(X_train, y_train)

joblib.dump(pipeline, "knn_breast_cancer.pkl")
# Out:
# ['knn_breast_cancer.pkl']

# %%
sample =  [[
    9.72, 18.22, 60.73, 288.1, 0.0695,
    0.02344, 0.0, 0.0, 0.1653, 0.06447,
    0.3539, 4.885, 2.23, 19.87, 0.007499,
    0.000979, 0.0, 0.0, 0.01938, 0.002256,
    9.968, 20.83, 62.25, 303.8, 0.07117,
    0.02729, 0.0, 0.0, 0.1909, 0.06559
]]

model = joblib.load("knn_breast_cancer.pkl")
pred = model.predict(sample)

print("Malignant" if pred[0] == 1 else "Benign")
# Out:
# Benign
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
new_data = [[
    19.18, 22.49, 127.5, 1148, 0.08523,
    0.1428, 0.1114, 0.06772, 0.1767, 0.05529,
    0.4357, 1.073, 3.833, 54.22, 0.005524,
    0.03698, 0.02706, 0.01221, 0.01415, 0.003397,
    23.36, 32.06, 166.4, 1688, 0.1322,
    0.5601, 0.3865, 0.1708, 0.3193, 0.09221
]]

model = joblib.load("knn_breast_cancer.pkl")
pred = model.predict(new_data)

print("Malignant" if pred[0] == 1 else "Benign")
# Out:
# Malignant
# c:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
